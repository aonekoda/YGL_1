# %% [markdown]
# # 파이썬 코딩의 기초
#
# jupyter notebook code cell 실행
# 실행하고자 하는 cell에 커서를 위치하고 다음과 같이 해당 셀을 실행할 수 있다.
#
# * `ctrl+enter` : 해당 셀을 실행하고 커서를 다음 셀로 이동하지 않는다.
# * `alt+enter` : 해당 셀을 실행하고 그 다음에 추가 셀을 하나 생성한다.
# * `shift+enter` : 해당 셀을 실행하고 다음 셀로 이동한다.

# %%
# 문자열을 output으로 출력한다.
print('이선화입니다.')
# Out:
# 이선화입니다.

# %%
# <- 이 기호로 시작하는 부분은 주석문 comment,설명을 적는다.
# 실행되는 줄은 아니다. 코드에 대한 설명을 쓴다.

# %% [markdown]
# # Markdown
#
# Markdown(마크다운)은 문서를 작성하는데 있어서 도움을 주는 언어이다.
# 코드나 분석에 대한 설명을 적을때 전달력과 설명력을 높일 수 있는 장점이 있다.
#
# 마크다운 문법을 사용한다.
#
# [마크다운 참조-위키백과](https://ko.wikipedia.org/wiki/%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4)
#
#
# # 큰 제목
# #### 작은 제목
#
# * 리스트1
# * 리스트2

# %%
# !로 시작하는 명령어는 운영체제 명령어를 실행한다.
# !python --version
# Out:
# Python 3.6.9

# %% [markdown]
# # 변수의 선언과 변수의 타입
#
# * 변수명 = 변수의 값 으로 변수를 선언한다.
# * 변수의 기본 데이터 타입
#     * 숫자형
#     * 논리형
#     * 문자형

# %%
name = "홍길동"
print(name)
# Out:
# 홍길동

# %%
# 변수의 이름은 대소문자를 구분한다.
NAME
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bdee1e0161a4> in <module>()
# ----> 1 NAME
#
# NameError: name 'NAME' is not defined

# %%
# 여러 변수에 값을 할당할 수 있다.
a = b = 0
print(a, b)
# Out:
# 0 0

# %%
a, b, c = 10, 20, 30
print(a, b, c)
# Out:
# 10 20 30

# %%
# 변수를 삭제한다.
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3f786850e387> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## 숫자형 변수

# %%
a, b = 10, 20

# %%
a + b
# Out:
# 30

# %%
a - b
# Out:
# -10

# %%
a * b
# Out:
# 200

# %%
a / b
# Out:
# 0.5

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3 # 정수 나눗셈 : 정수값을 리턴 작은 정수값을 리턴
# Out:
# 3

# %%
-10 // 3
# Out:
# -4

# %% [markdown]
# ### 논리형

# %%
3 == 3
# Out:
# True

# %%
3 != 4
# Out:
# True

# %%
( 3 == 3) | (3 != 4)
# Out:
# True

# %%
"짝수" if 10 % 2 == 0 else "홀수"
# Out:
# '짝수'

# %% [markdown]
# ### 문자형

# %%
x = "이선화"
type(x)
# Out:
# str

# %%
x = '명수가 "안녕"이라고 했다.'
print(x)
# Out:
# 명수가 "안녕"이라고 했다.

# %%
x = '''1번 
2번 
3번'''
print(x)
# Out:
# 1번
# 2번
# 3번

# %%
'100' + '200' # 문자열의 + 두 문자를 합쳐서 하나의 문자열로
# Out:
# '100200'

# %%
'이선화' * 3 # 문자열의 * 는 문자열 반복
# Out:
# '이선화이선화이선화'

# %%
# ?len

# %%
# 문자열의 길이
len("Hello World")
# Out:
# 11

# %%
'he' in 'hello' # 문자열의 포함 여부
# Out:
# True

# %% [markdown]
# ### 문자열의 인덱싱 슬라이싱

# %%
value = '안녕하세요. 반갑습니다.'

# %%
value[0]
# Out:
# '안'

# %%
value[-1]
# Out:
# '.'

# %%
value
# Out:
# '안녕하세요. 반갑습니다.'

# %%
value[0:1]
# Out:
# '안'

# %%
value[:: 2]
# Out:
# '안하요 갑니.'

# %% [markdown]
# ### 문자열의 포맷팅

# %%
myformat = '이름 : {}, 나이 :{}, 성별: {}'

# %%
myformat.format("이선화", 20, "여성")
# Out:
# '이름 : 이선화, 나이 :20, 성별: 여성'

# %%
myformat = '이름 : {name}, 나이 :{age}'

# %%
myformat.format(name='홍길동', age=20)
# Out:
# '이름 : 홍길동, 나이 :20'

# %%
"이름 : %s 나이: %d" % ('홍길동', 20)
# Out:
# '이름 : 홍길동 나이: 20'

# %%
"이 주스는 사과 %d%% 입니다." % (50)
# Out:
# '이 주스는 사과 50% 입니다.'

# %% [markdown]
# ### 문자열 메소드

# %%
"사과, 배, 귤".split(',')
# Out:
# ['사과', ' 배', ' 귤']

# %%
x = '        abc        '
print(x.rstrip())
# Out:
#         abc

# %%
'사과' not in "귤, 복숭아"
# Out:
# True

# %%
'helloworld'.count('l')
# Out:
# 3

# %%
"안녕하세요.".replace("안","가")
# Out:
# '가녕하세요.'

# %%
x = "안녕하세요. 반갑습니다."
x
# Out:
# '안녕하세요. 반갑습니다.'

# %%
x.index('가')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-92a8b39e62c0> in <module>()
# ----> 1 x.index('가')
#
# ValueError: substring not found

# %%
x.find('가')
# Out:
# -1

# %% [markdown]
# # 실습 하기

# %% [markdown]
# 화면에 "Hello World" 출력하기

# %% [markdown]
#  화면에 I'm a student. 출력하라. (중간에 '가 있음에 주의)

# %% [markdown]
# print 함수를 사용하여 3.141592의 값을 출력하라. 단, 출력된 값이 소수점 아래로 두 자리 숫자까지만 표시되도록 하라.
# (형식문자를 이용한 format)

# %% [markdown]
# "Hello"라는 문자열을 5회 반복하여 출력하시오.

# %% [markdown]
# mystring이라는 문자열의 길이를 출력하시오.
#
# ```
# >>> mystring = "안녕하세요. 반갑습니다."
# ```

# %% [markdown]
# 자동차 번호가 다음과 같을 때 뒤에 4자리만 출력하라.
# ```
# >>> license_plate = "24가 2210"
# ```

# %% [markdown]
# 변수 s와 t가 바인딩하는 문자열을 합쳐 출력하라.
#
# ```
# >>> s = "hello"
# >>> t = "python"
# ```

# %% [markdown]
# 다음 문자열에서 'python' 문자열의 빈도수를 출력하라.
# ```
# s = "python is widely used high-level language. python was conceived in the late 1980s"
# ```

# %% [markdown]
# 다음 x 변수가 짝수인지 홀수인지 출력하시오. (삼항연산자 사용)
#
# ```
# x = 9
# ```
